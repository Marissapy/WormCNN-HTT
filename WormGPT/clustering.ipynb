# %%
import pandas as pd
import glob
import numpy as np
import os

final_fixed_data = pd.read_csv("/data/yan/track/WormGPT/allnormalized_worm_data.csv")
# print(df.info())


print(final_fixed_data['head_velocity'].describe())
print(final_fixed_data['head_acceleration'].describe())
# Out:
# count    196353.000000
# mean          1.975349
# std           6.803452
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           2.236068
# max         626.388059
# Name: head_velocity, dtype: float64
# count    196225.000000
# mean         -0.000024
# std           9.339034
# min        -626.388059
# 25%          -2.000000
# 50%           0.000000
# 75%           2.000000
# max         626.388059
# Name: head_acceleration, dtype: float64

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib.colors import Normalize


final_fixed_data = pd.read_csv("allnormalized_worm_data.csv")

# 定义子图布局和坐标范围
fig, axes = plt.subplots(2, 2, figsize=(14, 12))
limits = [(50, 50), (100, 100), (200, 200), (400, 400)]  # 不同的坐标范围
titles = ["xlim/ylim: 50x50", "xlim/ylim: 100x100", "xlim/ylim: 200x200", "xlim/ylim: 400x400"]

# 归一化时间，用于颜色映射
norm = Normalize(vmin=final_fixed_data['head_velocity'].min(), vmax=3)
cmap = cm.cool  # 选择颜色映射

# 遍历每个范围，绘制子图
for ax, limit, title in zip(axes.flatten(), limits, titles):
    for sequence_id, group in final_fixed_data.groupby('SequenceID'):
        x = group['head_X']
        y = group['head_Y']
        time = group['head_velocity']
        
        # 绘制轨迹
        scatter = ax.scatter(x, y, c=time, cmap=cmap, norm=norm, s=0.01)
    
    # 设置坐标轴范围和标题
    ax.set_xlim(-limit[0], limit[0])
    ax.set_ylim(-limit[1], limit[1])
    ax.set_title(title)
    ax.set_xlabel("Normalized Head X")
    ax.set_ylabel("Normalized Head Y")

# 添加全局颜色条
cbar_ax = fig.add_axes([0.92, 0.15, 0.02, 0.7])  # [left, bottom, width, height] 定义颜色条的位置
cbar = fig.colorbar(scatter, cax=cbar_ax)
cbar.set_label('Time')

# 调整布局
plt.tight_layout(rect=[0, 0, 0.9, 1])  # 留出右侧空间给颜色条
plt.show()
# Out:
# /tmp/ipykernel_3102070/350411213.py:40: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 0.9, 1])  # 留出右侧空间给颜色条

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib.colors import Normalize


final_fixed_data = pd.read_csv("allnormalized_worm_data.csv")

# 定义子图布局和坐标范围
fig, axes = plt.subplots(2, 2, figsize=(14, 12))
limits = [(50, 50), (100, 100), (200, 200), (400, 400)]  # 不同的坐标范围
titles = ["xlim/ylim: 50x50", "xlim/ylim: 100x100", "xlim/ylim: 200x200", "xlim/ylim: 400x400"]

# 归一化时间，用于颜色映射
final_fixed_data['abs_acceleration'] = final_fixed_data['head_acceleration'].abs()

norm = Normalize(vmin=0, vmax=8)
cmap = cm.cool  # 选择颜色映射

# 遍历每个范围，绘制子图
for ax, limit, title in zip(axes.flatten(), limits, titles):
    for sequence_id, group in final_fixed_data.groupby('SequenceID'):
        x = group['head_X']
        y = group['head_Y']
        time = group['abs_acceleration']
        
        # 绘制轨迹
        scatter = ax.scatter(x, y, c=time, cmap=cmap, norm=norm, s=0.01)
    
    # 设置坐标轴范围和标题
    ax.set_xlim(-limit[0], limit[0])
    ax.set_ylim(-limit[1], limit[1])
    ax.set_title(title)
    ax.set_xlabel("Normalized Head X")
    ax.set_ylabel("Normalized Head Y")

# 添加全局颜色条
cbar_ax = fig.add_axes([0.92, 0.15, 0.02, 0.7])  # [left, bottom, width, height] 定义颜色条的位置
cbar = fig.colorbar(scatter, cax=cbar_ax)
cbar.set_label('Time')

# 调整布局
plt.tight_layout(rect=[0, 0, 0.9, 1])  # 留出右侧空间给颜色条
plt.show()
# Out:
# /tmp/ipykernel_3102070/393904515.py:42: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 0.9, 1])  # 留出右侧空间给颜色条

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib.colors import Normalize


final_fixed_data = pd.read_csv("allnormalized_worm_data.csv")

# 定义子图布局和坐标范围
fig, axes = plt.subplots(2, 2, figsize=(14, 12))
limits = [(50, 50), (100, 100), (200, 200), (400, 400)]  # 不同的坐标范围
titles = ["xlim/ylim: 50x50", "xlim/ylim: 100x100", "xlim/ylim: 200x200", "xlim/ylim: 400x400"]

norm = Normalize(vmin=0, vmax=8)
cmap = cm.cool  # 选择颜色映射

# 遍历每个范围，绘制子图
for ax, limit, title in zip(axes.flatten(), limits, titles):
    for sequence_id, group in final_fixed_data.groupby('SequenceID'):
        x = group['tail_X']
        y = group['tail_Y']
        time = group['tail_acceleration']
        
        # 绘制轨迹
        scatter = ax.scatter(x, y, c=time, cmap=cmap, norm=norm, s=0.01)
    
    # 设置坐标轴范围和标题
    ax.set_xlim(-limit[0], limit[0])
    ax.set_ylim(-limit[1], limit[1])
    ax.set_title(title)
    ax.set_xlabel("Normalized tail X")
    ax.set_ylabel("Normalized tail Y")

# 添加全局颜色条
cbar_ax = fig.add_axes([0.92, 0.15, 0.02, 0.7])  # [left, bottom, width, height] 定义颜色条的位置
cbar = fig.colorbar(scatter, cax=cbar_ax)
cbar.set_label('Time')

# 调整布局
plt.tight_layout(rect=[0, 0, 0.9, 1])  # 留出右侧空间给颜色条
plt.show()
# Out:
# /tmp/ipykernel_3102070/1165264924.py:39: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 0.9, 1])  # 留出右侧空间给颜色条
